# %% [markdown]
# # Importing the Libraries

# %%
# import data manipulation packages
import os
import random
import zipfile
import shutil
from shutil import copyfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# import deep learning tools 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Exctacting and Splitting The Dataset

# %%
shutil.rmtree('EYEAM Image Data')
shutil.rmtree('EYEAM Splitted Dataset')

# %%
local_zip = 'EYEAM_Image_Data.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall(os.getcwd())
zip_ref.close()

# %%
source_path = 'EYEAM Image Data'

for dir in os.listdir(source_path):
  i = 1
  for img in os.listdir(os.path.join(source_path, dir)):
    os.rename(os.path.join(source_path, dir, img), os.path.join(source_path, dir, dir) + f'_{i}' +
              os.path.splitext(os.path.join(source_path, dir, img))[1])
    i += 1

source_path_binturong = os.path.join(source_path, "Binturong")
source_path_koala = os.path.join(source_path, "Koala")
source_path_sanfords_brown_lemur = os.path.join(source_path, "Sanford_s Brown Lemur")
source_path_siau_island_tarsier = os.path.join(source_path, "Siau Island Tarsier")
source_path_walrus = os.path.join(source_path, "Walrus")
source_path_lemur_catta = os.path.join(source_path, "Lemur Catta")


# os.listdir returns a list containing all files under the given path
print(f"There are {len(os.listdir(source_path_binturong))} images of Binturong.")
print(f"There are {len(os.listdir(source_path_koala))} images of Koala.")
print(f"There are {len(os.listdir(source_path_sanfords_brown_lemur))} images of Sanfords Brown Lemur.")
print(f"There are {len(os.listdir(source_path_siau_island_tarsier))} images of Siau Island Tarsier.")
print(f"There are {len(os.listdir(source_path_walrus))} images of Walrus.")
print(f"There are {len(os.listdir(source_path_lemur_catta))} images of Lemur Catta.")
# Out:
# There are 50 images of Binturong.
# There are 50 images of Koala.
# There are 50 images of Sanfords Brown Lemur.
# There are 50 images of Siau Island Tarsier.
# There are 50 images of Walrus.
# There are 50 images of Lemur Catta.

# %%
# Define root directory
root_dir = 'EYEAM Splitted Dataset'

os.mkdir(root_dir)

# Empty directory to prevent FileExistsError is the function is run several times
if os.path.exists(root_dir):
  shutil.rmtree(root_dir)

# Creating Training and Testing Directories
def create_train_test_dirs(root_path):
  training_dir = os.path.join(root_path, "training")
  testing_dir  = os.path.join(root_path, "testing")

  training_binturong_dir = os.path.join(training_dir, "binturong")
  training_koala_dir = os.path.join(training_dir, "koala")
  training_sanfords_brown_lemur_dir = os.path.join(training_dir, "sanfords_brown_lemur")
  training_siau_island_tarsier_dir = os.path.join(training_dir, "siau_island_tarsier")
  training_walrus_dir = os.path.join(training_dir, "walrus")
  training_lemur_catta_dir = os.path.join(training_dir, "lemur_catta")

  testing_binturong_dir = os.path.join(testing_dir, "binturong")
  testing_koala_dir = os.path.join(testing_dir, "koala")
  testing_sanfords_brown_lemur_dir = os.path.join(testing_dir, "sanfords_brown_lemur")
  testing_siau_island_tarsier_dir = os.path.join(testing_dir, "siau_island_tarsier")
  testing_walrus_dir = os.path.join(testing_dir, "walrus")
  testing_lemur_catta_dir = os.path.join(testing_dir, "lemur_catta")

  os.makedirs(training_binturong_dir, exist_ok = True)
  os.makedirs(training_koala_dir, exist_ok = True)
  os.makedirs(training_sanfords_brown_lemur_dir, exist_ok = True)
  os.makedirs(training_siau_island_tarsier_dir, exist_ok = True)
  os.makedirs(training_walrus_dir, exist_ok = True)
  os.makedirs(training_lemur_catta_dir, exist_ok = True)
  
  os.makedirs(testing_binturong_dir, exist_ok = True)
  os.makedirs(testing_koala_dir, exist_ok = True)
  os.makedirs(testing_sanfords_brown_lemur_dir, exist_ok = True)
  os.makedirs(testing_siau_island_tarsier_dir, exist_ok = True)
  os.makedirs(testing_walrus_dir, exist_ok = True)
  os.makedirs(testing_lemur_catta_dir, exist_ok = True)

try:
  create_train_test_dirs(root_path=root_dir)
except FileExistsError:
  print("You should not be seeing this since the upper directory is removed beforehand")

# %%
# Test your create_train_test_dirs function
for rootdir, dirs, files in os.walk(root_dir):
    for subdir in dirs:
        print(os.path.join(rootdir, subdir))
# Out:
# EYEAM Splitted Dataset\testing
# EYEAM Splitted Dataset\training
# EYEAM Splitted Dataset\testing\binturong
# EYEAM Splitted Dataset\testing\koala
# EYEAM Splitted Dataset\testing\lemur_catta
# EYEAM Splitted Dataset\testing\sanfords_brown_lemur
# EYEAM Splitted Dataset\testing\siau_island_tarsier
# EYEAM Splitted Dataset\testing\walrus
# EYEAM Splitted Dataset\training\binturong
# EYEAM Splitted Dataset\training\koala
# EYEAM Splitted Dataset\training\lemur_catta
# EYEAM Splitted Dataset\training\sanfords_brown_lemur
# EYEAM Splitted Dataset\training\siau_island_tarsier
# EYEAM Splitted Dataset\training\walrus

# %%
# Splitting the data into training and testing
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
  files = []
  for file_name in os.listdir(SOURCE):
    the_file = SOURCE + file_name
    if os.path.getsize(the_file) > 0:
      files.append(file_name)
    else:
      print(file_name + " is zero length, so ignoring.")

  training_length = int(len(files) * SPLIT_SIZE)
  testing_length = int(len(files) - training_length)
  shuffled_set = random.sample(files, len(files))
  training_set = shuffled_set[0:training_length]
  testing_set = shuffled_set[training_length:]

  for file_name in training_set:
    file_this = SOURCE + file_name
    dest     = TRAINING + file_name
    copyfile(file_this, dest)

  for file_name in testing_set:
      file_this = SOURCE + file_name
      dest     = TESTING + file_name
      copyfile(file_this, dest)
  pass

# %%
# Test your split_data function

# Define paths
BINTURONG_SOURCE_DIR = "EYEAM Image Data/Binturong/"
KOALA_SOURCE_DIR = "EYEAM Image Data/Koala/"
SANFORD_S_BROWN_LEMUR_SOURCE_DIR = "EYEAM Image Data/Sanford_s Brown Lemur/"
SIAU_ISLAND_TARSIER_SOURCE_DIR = "EYEAM Image Data/Siau Island Tarsier/"
WALRUS_SOURCE_DIR = "EYEAM Image Data/Walrus/"
LEMUR_CATTA_SOURCE_DIR = "EYEAM Image Data/Lemur Catta/"

TRAINING_DIR = "EYEAM Splitted Dataset/training/"
TESTING_DIR = "EYEAM Splitted Dataset/testing/"

TRAINING_BINTURONG_DIR = os.path.join(TRAINING_DIR, "binturong/")
TESTING_BINTURONG_DIR = os.path.join(TESTING_DIR, "binturong/")

TRAINING_KOALA_DIR = os.path.join(TRAINING_DIR, "koala/")
TESTING_KOALA_DIR = os.path.join(TESTING_DIR, "koala/")

TRAINING_SANFORD_S_BROWN_LEMUR_DIR = os.path.join(TRAINING_DIR, "sanfords_brown_lemur/")
TESTING_SANFORD_S_BROWN_LEMUR_DIR = os.path.join(TESTING_DIR, "sanfords_brown_lemur/")

TRAINING_SIAU_ISLAND_TARSIER_DIR = os.path.join(TRAINING_DIR, "siau_island_tarsier/")
TESTING_SIAU_ISLAND_TARSIER_DIR = os.path.join(TESTING_DIR, "siau_island_tarsier/")

TRAINING_WALRUS_DIR = os.path.join(TRAINING_DIR, "walrus/")
TESTING_WALRUS_DIR = os.path.join(TESTING_DIR, "walrus/")

TRAINING_LEMUR_CATTA_DIR = os.path.join(TRAINING_DIR, "lemur_catta/")
TESTING_LEMUR_CATTA_DIR = os.path.join(TESTING_DIR, "lemur_catta/")

# Empty directories in case you run this cell multiple times
if len(os.listdir(TRAINING_BINTURONG_DIR)) > 0:
  for file in os.scandir(TRAINING_BINTURONG_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_KOALA_DIR)) > 0:
  for file in os.scandir(TRAINING_KOALA_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_SANFORD_S_BROWN_LEMUR_DIR)) > 0:
  for file in os.scandir(TRAINING_SANFORD_S_BROWN_LEMUR_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_SIAU_ISLAND_TARSIER_DIR)) > 0:
  for file in os.scandir(TRAINING_SIAU_ISLAND_TARSIER_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_WALRUS_DIR)) > 0:
  for file in os.scandir(TRAINING_WALRUS_DIR):
    os.remove(file.path)

if len(os.listdir(TESTING_BINTURONG_DIR)) > 0:
  for file in os.scandir(TESTING_BINTURONG_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_KOALA_DIR)) > 0:
  for file in os.scandir(TESTING_KOALA_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_SANFORD_S_BROWN_LEMUR_DIR)) > 0:
  for file in os.scandir(TESTING_SANFORD_S_BROWN_LEMUR_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_SIAU_ISLAND_TARSIER_DIR)) > 0:
  for file in os.scandir(TESTING_SIAU_ISLAND_TARSIER_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_WALRUS_DIR)) > 0:
  for file in os.scandir(TESTING_WALRUS_DIR):
    os.remove(file.path)

# Define proportion of images used for training
split_size = .7

# Run the function
# NOTE: Messages about zero length images should be printed out
split_data(BINTURONG_SOURCE_DIR, TRAINING_BINTURONG_DIR, TESTING_BINTURONG_DIR, split_size)
split_data(KOALA_SOURCE_DIR, TRAINING_KOALA_DIR, TESTING_KOALA_DIR, split_size)
split_data(SANFORD_S_BROWN_LEMUR_SOURCE_DIR, TRAINING_SANFORD_S_BROWN_LEMUR_DIR, TESTING_SANFORD_S_BROWN_LEMUR_DIR, split_size)
split_data(SIAU_ISLAND_TARSIER_SOURCE_DIR, TRAINING_SIAU_ISLAND_TARSIER_DIR, TESTING_SIAU_ISLAND_TARSIER_DIR, split_size)
split_data(WALRUS_SOURCE_DIR, TRAINING_WALRUS_DIR, TESTING_WALRUS_DIR, split_size)
split_data(LEMUR_CATTA_SOURCE_DIR, TRAINING_LEMUR_CATTA_DIR, TESTING_LEMUR_CATTA_DIR, split_size)

# Check that the number of images matches the expected output
print(f"There are {len(os.listdir(TRAINING_BINTURONG_DIR))} images of binturongs for training")
print(f"There are {len(os.listdir(TESTING_BINTURONG_DIR))} images of binturongs for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_KOALA_DIR))} images of koalas for training")
print(f"There are {len(os.listdir(TESTING_KOALA_DIR))} images of koalas for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_SANFORD_S_BROWN_LEMUR_DIR))} images of sanford's brown_lemurs for training")
print(f"There are {len(os.listdir(TESTING_SANFORD_S_BROWN_LEMUR_DIR))} images of sanford's brown_lemurs for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_SIAU_ISLAND_TARSIER_DIR))} images of siau island tarsiers for training")
print(f"There are {len(os.listdir(TESTING_SIAU_ISLAND_TARSIER_DIR))} images of siau island tarsiers for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_WALRUS_DIR))} images of walruses for training")
print(f"There are {len(os.listdir(TESTING_WALRUS_DIR))} images of walruses for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_LEMUR_CATTA_DIR))} images of lemur cattas for training")
print(f"There are {len(os.listdir(TESTING_LEMUR_CATTA_DIR))} images of lemur cattas for testing")
# Out:
# There are 35 images of binturongs for training
# There are 15 images of binturongs for testing
#
#
# There are 35 images of koalas for training
# There are 15 images of koalas for testing
#
#
# There are 35 images of sanford's brown_lemurs for training
# There are 15 images of sanford's brown_lemurs for testing
#
#
# There are 35 images of siau island tarsiers for training
# There are 15 images of siau island tarsiers for testing
#
#
# There are 35 images of walruses for training
# There are 15 images of walruses for testing
#
#
# There are 35 images of lemur cattas for training
# There are 15 images of lemur cattas for testing

# %% [markdown]
# # Setting up ImageDataGenerator

# %%
# GRADED FUNCTION: train_val_generators
def train_val_generators(TRAINING_DIR, VALIDATION_DIR):
  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  train_datagen = ImageDataGenerator(rescale = 1.0/255.,
                                     rotation_range=30,
                                     width_shift_range=0.15,
                                     height_shift_range=0.15,
                                     shear_range=0.15,
                                     zoom_range=0.15,
                                     horizontal_flip=True,
                                     fill_mode='nearest')

  # Pass in the appropiate arguments to the flow_from_directory method
  train_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                      batch_size=50,
                                                      class_mode="binary",
                                                      target_size=(300, 300))

  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  validation_datagen = ImageDataGenerator(rescale = 1.0/255.)

  # Pass in the appropiate arguments to the flow_from_directory method
  validation_generator = validation_datagen.flow_from_directory(directory=VALIDATION_DIR,
                                                      batch_size=50,
                                                      class_mode="binary",
                                                      target_size=(300, 300))
  
  return train_generator, validation_generator

# %%
# Test your generators
train_generator, validation_generator = train_val_generators(TRAINING_DIR, TESTING_DIR)
# Out:
# Found 210 images belonging to 6 classes.
# Found 90 images belonging to 6 classes.

# %% [markdown]
# # Building and Training the Model

# %%
# Creating model
def create_model():
  model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(32,(3,3), activation = 'relu', input_shape=(300,300,3)),
      tf.keras.layers.MaxPooling2D(2,2),
      tf.keras.layers.Conv2D(64,(3,3), activation = 'relu'),
      tf.keras.layers.MaxPooling2D(2,2),
      tf.keras.layers.Conv2D(128,(3,3), activation = 'relu'),
      tf.keras.layers.MaxPooling2D(2,2),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(512, activation = 'relu'),
      tf.keras.layers.Dense(6, activation='softmax')
  ])


  
  model.compile(optimizer=Adam(learning_rate=0.001),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']) 

  return model

# %%
# Get the untrained model
model = create_model()

# Training the model
history = model.fit(train_generator,
                    steps_per_epoch = 3,
                    epochs=15,
                    validation_data=validation_generator)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 24s 11s/step - loss: 20.7577 - accuracy: 0.1545 - val_loss: 7.3978 - val_accuracy: 0.1667
# Epoch 2/15
# 3/3 [==============================] - 23s 11s/step - loss: 2.6290 - accuracy: 0.1909 - val_loss: 1.9025 - val_accuracy: 0.1667
# Epoch 3/15
# 3/3 [==============================] - 27s 9s/step - loss: 1.8176 - accuracy: 0.1800 - val_loss: 1.7812 - val_accuracy: 0.2111
# Epoch 4/15
# 3/3 [==============================] - 22s 7s/step - loss: 1.7709 - accuracy: 0.2273 - val_loss: 1.7506 - val_accuracy: 0.1778
# Epoch 5/15
# 3/3 [==============================] - 25s 9s/step - loss: 1.7416 - accuracy: 0.2267 - val_loss: 1.6932 - val_accuracy: 0.2000
# Epoch 6/15
# 3/3 [==============================] - 22s 8s/step - loss: 1.6831 - accuracy: 0.2909 - val_loss: 1.6975 - val_accuracy: 0.2667
# Epoch 7/15
# 3/3 [==============================] - 28s 11s/step - loss: 1.5858 - accuracy: 0.4364 - val_loss: 1.7251 - val_accuracy: 0.2556
# Epoch 8/15
# 3/3 [==============================] - 32s 12s/step - loss: 1.5999 - accuracy: 0.3267 - val_loss: 1.3470 - val_accuracy: 0.4000
# Epoch 9/15
# 3/3 [==============================] - 24s 8s/step - loss: 1.4597 - accuracy: 0.3727 - val_loss: 1.4101 - val_accuracy: 0.3667
# Epoch 10/15
# 3/3 [==============================] - 24s 9s/step - loss: 1.3287 - accuracy: 0.4273 - val_loss: 1.6158 - val_accuracy: 0.4444
# Epoch 11/15
# 3/3 [==============================] - 32s 12s/step - loss: 1.5633 - accuracy: 0.3333 - val_loss: 1.2673 - val_accuracy: 0.5444
# Epoch 12/15
# 3/3 [==============================] - 35s 13s/step - loss: 1.3008 - accuracy: 0.4933 - val_loss: 1.3318 - val_accuracy: 0.4667
# Epoch 13/15
# 3/3 [==============================] - 33s 12s/step - loss: 1.2440 - accuracy: 0.5133 - val_loss: 1.2958 - val_accuracy: 0.4444
# Epoch 14/15
# 3/3 [==============================] - 33s 12s/step - loss: 1.1926 - accuracy: 0.5133 - val_loss: 1.0751 - val_accuracy: 0.5778
# Epoch 15/15
# 3/3 [==============================] - 26s 8s/step - loss: 1.1823 - accuracy: 0.5545 - val_loss: 1.0481 - val_accuracy: 0.5444

# %%
pd.DataFrame(history.history)
# Out:
#          loss  accuracy  val_loss  val_accuracy
# 0   20.757650  0.154545  7.397751      0.166667
# 1    2.628978  0.190909  1.902491      0.166667
# 2    1.817624  0.180000  1.781212      0.211111
# 3    1.770908  0.227273  1.750649      0.177778
# 4    1.741578  0.226667  1.693195      0.200000
# 5    1.683110  0.290909  1.697469      0.266667
# 6    1.585835  0.436364  1.725084      0.255556
# 7    1.599937  0.326667  1.347006      0.400000
# 8    1.459662  0.372727  1.410089      0.366667
# 9    1.328746  0.427273  1.615845      0.444444
# 10   1.563310  0.333333  1.267256      0.544444
# 11   1.300764  0.493333  1.331767      0.466667
# 12   1.244025  0.513333  1.295784      0.444444
# 13   1.192620  0.513333  1.075084      0.577778
# 14   1.182316  0.554545  1.048134      0.544444

# %% [markdown]
# # Prediction Test

# %%
# predicting images

labels = ["Binturong", "Koala", "Lemur Catta", "Sanford's Brown Lemur", "Siau Island Tarsier", "Walrus"]

src = 'EYEAM Image Data'
res_dict = {}

import time
st = time.time()

for animals in os.listdir(src):
    for img in os.listdir(os.path.join(src, animals)):
        path = os.path.join(src, animals, img)

        #path = 'EYEAM Image Data\\Binturong\\Binturong_2.jpeg'
        img = tf.keras.utils.load_img(path, target_size=(300, 300))
        x = tf.keras.utils.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = x/255

        images = np.vstack([x])
        classes = labels[np.argmax(model.predict(images))]

        #print(path)
        #print(classes)

        if classes in res_dict.keys():
          res_dict[classes] += 1
        else:
          res_dict[classes] = 1

et = time.time()

print('Time elapsed: {} seconds.'.format(et-st))

res_dict
# Out:
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 101ms/step
# Time elapsed: 68.77162909507751 seconds.
# {'Binturong': 96,
#  'Koala': 19,
#  'Siau Island Tarsier': 67,
#  "Sanford's Brown Lemur": 15,
#  'Walrus': 59,
#  'Lemur Catta': 44}

# %% [markdown]
# # Saving the Model

# %%
# Saving model into h5 format
from datetime import datetime
date = datetime.now().strftime("%Y_%m_%d-%I-%M-%S-%p")
model.save(f'H5 Models/model_1_baseline_augmentation ({date}).h5')

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, label="Training Accuracy", color='red')
plt.plot(epochs, val_acc, label="Validation Accuracy", color='blue')
plt.title('Training and Validation Accuracy')
plt.ylabel('Values')
plt.xlabel('Epochs')
plt.legend(loc="upper left")
plt.show()
print("")

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs,loss, label="Training Loss", color='red')
plt.plot(epochs,val_loss, label="Validation Loss", color='blue')
plt.title('Training and Validation Loss')
plt.ylabel('Values')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()
