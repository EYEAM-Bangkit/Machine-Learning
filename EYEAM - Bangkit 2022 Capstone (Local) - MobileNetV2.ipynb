# %% [markdown]
# # Importing the Libraries

# %%
# import data manipulation packages
import os
import random
import zipfile
import shutil
from shutil import copyfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# import deep learning tools 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Exctacting and Splitting The Dataset

# %%
shutil.rmtree('EYEAM Image Data')
shutil.rmtree('EYEAM Splitted Dataset')

# %%
local_zip = 'EYEAM_Image_Data.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall(os.getcwd())
zip_ref.close()

# %%
source_path = 'EYEAM Image Data'

for dir in os.listdir(source_path):
  i = 1
  for img in os.listdir(os.path.join(source_path, dir)):
    os.rename(os.path.join(source_path, dir, img), os.path.join(source_path, dir, dir) + f'_{i}' +
              os.path.splitext(os.path.join(source_path, dir, img))[1])
    i += 1

source_path_binturong = os.path.join(source_path, "Binturong")
source_path_koala = os.path.join(source_path, "Koala")
source_path_sanfords_brown_lemur = os.path.join(source_path, "Sanford_s Brown Lemur")
source_path_siau_island_tarsier = os.path.join(source_path, "Siau Island Tarsier")
source_path_walrus = os.path.join(source_path, "Walrus")
source_path_lemur_catta = os.path.join(source_path, "Lemur Catta")


# os.listdir returns a list containing all files under the given path
print(f"There are {len(os.listdir(source_path_binturong))} images of Binturong.")
print(f"There are {len(os.listdir(source_path_koala))} images of Koala.")
print(f"There are {len(os.listdir(source_path_sanfords_brown_lemur))} images of Sanfords Brown Lemur.")
print(f"There are {len(os.listdir(source_path_siau_island_tarsier))} images of Siau Island Tarsier.")
print(f"There are {len(os.listdir(source_path_walrus))} images of Walrus.")
print(f"There are {len(os.listdir(source_path_lemur_catta))} images of Lemur Catta.")
# Out:
# There are 50 images of Binturong.
# There are 50 images of Koala.
# There are 50 images of Sanfords Brown Lemur.
# There are 50 images of Siau Island Tarsier.
# There are 50 images of Walrus.
# There are 50 images of Lemur Catta.

# %%
# Define root directory
root_dir = 'EYEAM Splitted Dataset'

os.mkdir(root_dir)

# Empty directory to prevent FileExistsError is the function is run several times
if os.path.exists(root_dir):
  shutil.rmtree(root_dir)

# Creating Training and Testing Directories
def create_train_test_dirs(root_path):
  training_dir = os.path.join(root_path, "training")
  testing_dir  = os.path.join(root_path, "testing")

  training_binturong_dir = os.path.join(training_dir, "binturong")
  training_koala_dir = os.path.join(training_dir, "koala")
  training_sanfords_brown_lemur_dir = os.path.join(training_dir, "sanfords_brown_lemur")
  training_siau_island_tarsier_dir = os.path.join(training_dir, "siau_island_tarsier")
  training_walrus_dir = os.path.join(training_dir, "walrus")
  training_lemur_catta_dir = os.path.join(training_dir, "lemur_catta")

  testing_binturong_dir = os.path.join(testing_dir, "binturong")
  testing_koala_dir = os.path.join(testing_dir, "koala")
  testing_sanfords_brown_lemur_dir = os.path.join(testing_dir, "sanfords_brown_lemur")
  testing_siau_island_tarsier_dir = os.path.join(testing_dir, "siau_island_tarsier")
  testing_walrus_dir = os.path.join(testing_dir, "walrus")
  testing_lemur_catta_dir = os.path.join(testing_dir, "lemur_catta")

  os.makedirs(training_binturong_dir, exist_ok = True)
  os.makedirs(training_koala_dir, exist_ok = True)
  os.makedirs(training_sanfords_brown_lemur_dir, exist_ok = True)
  os.makedirs(training_siau_island_tarsier_dir, exist_ok = True)
  os.makedirs(training_walrus_dir, exist_ok = True)
  os.makedirs(training_lemur_catta_dir, exist_ok = True)
  
  os.makedirs(testing_binturong_dir, exist_ok = True)
  os.makedirs(testing_koala_dir, exist_ok = True)
  os.makedirs(testing_sanfords_brown_lemur_dir, exist_ok = True)
  os.makedirs(testing_siau_island_tarsier_dir, exist_ok = True)
  os.makedirs(testing_walrus_dir, exist_ok = True)
  os.makedirs(testing_lemur_catta_dir, exist_ok = True)

try:
  create_train_test_dirs(root_path=root_dir)
except FileExistsError:
  print("You should not be seeing this since the upper directory is removed beforehand")

# %%
# Test your create_train_test_dirs function
for rootdir, dirs, files in os.walk(root_dir):
    for subdir in dirs:
        print(os.path.join(rootdir, subdir))
# Out:
# EYEAM Splitted Dataset\testing
# EYEAM Splitted Dataset\training
# EYEAM Splitted Dataset\testing\binturong
# EYEAM Splitted Dataset\testing\koala
# EYEAM Splitted Dataset\testing\lemur_catta
# EYEAM Splitted Dataset\testing\sanfords_brown_lemur
# EYEAM Splitted Dataset\testing\siau_island_tarsier
# EYEAM Splitted Dataset\testing\walrus
# EYEAM Splitted Dataset\training\binturong
# EYEAM Splitted Dataset\training\koala
# EYEAM Splitted Dataset\training\lemur_catta
# EYEAM Splitted Dataset\training\sanfords_brown_lemur
# EYEAM Splitted Dataset\training\siau_island_tarsier
# EYEAM Splitted Dataset\training\walrus

# %%
# Splitting the data into training and testing
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
  files = []
  for file_name in os.listdir(SOURCE):
    the_file = SOURCE + file_name
    if os.path.getsize(the_file) > 0:
      files.append(file_name)
    else:
      print(file_name + " is zero length, so ignoring.")

  training_length = int(len(files) * SPLIT_SIZE)
  testing_length = int(len(files) - training_length)
  shuffled_set = random.sample(files, len(files))
  training_set = shuffled_set[0:training_length]
  testing_set = shuffled_set[training_length:]

  for file_name in training_set:
    file_this = SOURCE + file_name
    dest     = TRAINING + file_name
    copyfile(file_this, dest)

  for file_name in testing_set:
      file_this = SOURCE + file_name
      dest     = TESTING + file_name
      copyfile(file_this, dest)
  pass

# %%
# Test your split_data function

# Define paths
BINTURONG_SOURCE_DIR = "EYEAM Image Data/Binturong/"
KOALA_SOURCE_DIR = "EYEAM Image Data/Koala/"
SANFORD_S_BROWN_LEMUR_SOURCE_DIR = "EYEAM Image Data/Sanford_s Brown Lemur/"
SIAU_ISLAND_TARSIER_SOURCE_DIR = "EYEAM Image Data/Siau Island Tarsier/"
WALRUS_SOURCE_DIR = "EYEAM Image Data/Walrus/"
LEMUR_CATTA_SOURCE_DIR = "EYEAM Image Data/Lemur Catta/"

TRAINING_DIR = "EYEAM Splitted Dataset/training/"
TESTING_DIR = "EYEAM Splitted Dataset/testing/"

TRAINING_BINTURONG_DIR = os.path.join(TRAINING_DIR, "binturong/")
TESTING_BINTURONG_DIR = os.path.join(TESTING_DIR, "binturong/")

TRAINING_KOALA_DIR = os.path.join(TRAINING_DIR, "koala/")
TESTING_KOALA_DIR = os.path.join(TESTING_DIR, "koala/")

TRAINING_SANFORD_S_BROWN_LEMUR_DIR = os.path.join(TRAINING_DIR, "sanfords_brown_lemur/")
TESTING_SANFORD_S_BROWN_LEMUR_DIR = os.path.join(TESTING_DIR, "sanfords_brown_lemur/")

TRAINING_SIAU_ISLAND_TARSIER_DIR = os.path.join(TRAINING_DIR, "siau_island_tarsier/")
TESTING_SIAU_ISLAND_TARSIER_DIR = os.path.join(TESTING_DIR, "siau_island_tarsier/")

TRAINING_WALRUS_DIR = os.path.join(TRAINING_DIR, "walrus/")
TESTING_WALRUS_DIR = os.path.join(TESTING_DIR, "walrus/")

TRAINING_LEMUR_CATTA_DIR = os.path.join(TRAINING_DIR, "lemur_catta/")
TESTING_LEMUR_CATTA_DIR = os.path.join(TESTING_DIR, "lemur_catta/")

# Empty directories in case you run this cell multiple times
if len(os.listdir(TRAINING_BINTURONG_DIR)) > 0:
  for file in os.scandir(TRAINING_BINTURONG_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_KOALA_DIR)) > 0:
  for file in os.scandir(TRAINING_KOALA_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_SANFORD_S_BROWN_LEMUR_DIR)) > 0:
  for file in os.scandir(TRAINING_SANFORD_S_BROWN_LEMUR_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_SIAU_ISLAND_TARSIER_DIR)) > 0:
  for file in os.scandir(TRAINING_SIAU_ISLAND_TARSIER_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_WALRUS_DIR)) > 0:
  for file in os.scandir(TRAINING_WALRUS_DIR):
    os.remove(file.path)

if len(os.listdir(TESTING_BINTURONG_DIR)) > 0:
  for file in os.scandir(TESTING_BINTURONG_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_KOALA_DIR)) > 0:
  for file in os.scandir(TESTING_KOALA_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_SANFORD_S_BROWN_LEMUR_DIR)) > 0:
  for file in os.scandir(TESTING_SANFORD_S_BROWN_LEMUR_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_SIAU_ISLAND_TARSIER_DIR)) > 0:
  for file in os.scandir(TESTING_SIAU_ISLAND_TARSIER_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_WALRUS_DIR)) > 0:
  for file in os.scandir(TESTING_WALRUS_DIR):
    os.remove(file.path)

# Define proportion of images used for training
split_size = .7

# Run the function
# NOTE: Messages about zero length images should be printed out
split_data(BINTURONG_SOURCE_DIR, TRAINING_BINTURONG_DIR, TESTING_BINTURONG_DIR, split_size)
split_data(KOALA_SOURCE_DIR, TRAINING_KOALA_DIR, TESTING_KOALA_DIR, split_size)
split_data(SANFORD_S_BROWN_LEMUR_SOURCE_DIR, TRAINING_SANFORD_S_BROWN_LEMUR_DIR, TESTING_SANFORD_S_BROWN_LEMUR_DIR, split_size)
split_data(SIAU_ISLAND_TARSIER_SOURCE_DIR, TRAINING_SIAU_ISLAND_TARSIER_DIR, TESTING_SIAU_ISLAND_TARSIER_DIR, split_size)
split_data(WALRUS_SOURCE_DIR, TRAINING_WALRUS_DIR, TESTING_WALRUS_DIR, split_size)
split_data(LEMUR_CATTA_SOURCE_DIR, TRAINING_LEMUR_CATTA_DIR, TESTING_LEMUR_CATTA_DIR, split_size)

# Check that the number of images matches the expected output
print(f"There are {len(os.listdir(TRAINING_BINTURONG_DIR))} images of binturongs for training")
print(f"There are {len(os.listdir(TESTING_BINTURONG_DIR))} images of binturongs for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_KOALA_DIR))} images of koalas for training")
print(f"There are {len(os.listdir(TESTING_KOALA_DIR))} images of koalas for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_SANFORD_S_BROWN_LEMUR_DIR))} images of sanford's brown_lemurs for training")
print(f"There are {len(os.listdir(TESTING_SANFORD_S_BROWN_LEMUR_DIR))} images of sanford's brown_lemurs for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_SIAU_ISLAND_TARSIER_DIR))} images of siau island tarsiers for training")
print(f"There are {len(os.listdir(TESTING_SIAU_ISLAND_TARSIER_DIR))} images of siau island tarsiers for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_WALRUS_DIR))} images of walruses for training")
print(f"There are {len(os.listdir(TESTING_WALRUS_DIR))} images of walruses for testing")

print(f"\n\nThere are {len(os.listdir(TRAINING_LEMUR_CATTA_DIR))} images of lemur cattas for training")
print(f"There are {len(os.listdir(TESTING_LEMUR_CATTA_DIR))} images of lemur cattas for testing")
# Out:
# There are 35 images of binturongs for training
# There are 15 images of binturongs for testing
#
#
# There are 35 images of koalas for training
# There are 15 images of koalas for testing
#
#
# There are 35 images of sanford's brown_lemurs for training
# There are 15 images of sanford's brown_lemurs for testing
#
#
# There are 35 images of siau island tarsiers for training
# There are 15 images of siau island tarsiers for testing
#
#
# There are 35 images of walruses for training
# There are 15 images of walruses for testing
#
#
# There are 35 images of lemur cattas for training
# There are 15 images of lemur cattas for testing

# %% [markdown]
# # Setting up ImageDataGenerator

# %%
# GRADED FUNCTION: train_val_generators
def train_val_generators(TRAINING_DIR, VALIDATION_DIR):
  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  train_datagen = ImageDataGenerator(rescale = 1.0/255.,
                                     rotation_range=45,
                                     width_shift_range=0.15,
                                     height_shift_range=0.15,
                                     shear_range=0.15,
                                     zoom_range=0.15,
                                     horizontal_flip=True,
                                     fill_mode='nearest')

  # Pass in the appropiate arguments to the flow_from_directory method
  train_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                      batch_size=50,
                                                      class_mode="binary",
                                                      target_size=(224, 224))

  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  validation_datagen = ImageDataGenerator(rescale = 1.0/255.)

  # Pass in the appropiate arguments to the flow_from_directory method
  validation_generator = validation_datagen.flow_from_directory(directory=VALIDATION_DIR,
                                                      batch_size=50,
                                                      class_mode="binary",
                                                      target_size=(224, 224))
  
  return train_generator, validation_generator

# %%
# Test your generators
train_generator, validation_generator = train_val_generators(TRAINING_DIR, TESTING_DIR)
# Out:
# Found 210 images belonging to 6 classes.
# Found 90 images belonging to 6 classes.

# %% [markdown]
# # Transfer Learning

# %%
# Import the inception model  
from tensorflow.keras.applications import MobileNetV2

# Creating pre-trained model
def create_pre_trained_model():
  pre_trained_model = MobileNetV2(input_shape = (224, 224, 3),
                                  include_top = False, 
                                  weights = 'imagenet') 

  for the_layer in pre_trained_model.layers:
    the_layer.trainable = False

  return pre_trained_model

# %%
pre_trained_model = create_pre_trained_model()

# Print the model summary
#pre_trained_model.summary()

# %%
total_params = pre_trained_model.count_params()
num_trainable_params = sum([w.shape.num_elements() for w in pre_trained_model.trainable_weights])

print(f"There are {total_params:,} total parameters in this model.")
print(f"There are {num_trainable_params:,} trainable parameters in this model.")
# Out:
# There are 2,257,984 total parameters in this model.
# There are 0 trainable parameters in this model.

# %% [markdown]
# # Pipelining and Building the Model

# %%
def output_of_last_layer(pre_trained_model):
  last_desired_layer = pre_trained_model.get_layer('block_14_project')
  print('last layer output shape: ', last_desired_layer.output_shape)
  last_output = last_desired_layer.output
  print('last layer output: ', last_output)

  return last_output

# %%
# Pilih layer dari sini. Ambil yang relatif di bawah, lalu namanya taruh di 'get_layer' dari cell di atas.
for the_layer in pre_trained_model.layers:
    print(the_layer.name)
# Out:
# input_3
# Conv1
# bn_Conv1
# Conv1_relu
# expanded_conv_depthwise
# expanded_conv_depthwise_BN
# expanded_conv_depthwise_relu
# expanded_conv_project
# expanded_conv_project_BN
# block_1_expand
# block_1_expand_BN
# block_1_expand_relu
# block_1_pad
# block_1_depthwise
# block_1_depthwise_BN
# block_1_depthwise_relu
# block_1_project
# block_1_project_BN
# block_2_expand
# block_2_expand_BN
# block_2_expand_relu
# block_2_depthwise
# block_2_depthwise_BN
# block_2_depthwise_relu
# block_2_project
# block_2_project_BN
# block_2_add
# block_3_expand
# block_3_expand_BN
# block_3_expand_relu
# block_3_pad
# block_3_depthwise
# block_3_depthwise_BN
# block_3_depthwise_relu
# block_3_project
# block_3_project_BN
# block_4_expand
# block_4_expand_BN
# block_4_expand_relu
# block_4_depthwise
# block_4_depthwise_BN
# block_4_depthwise_relu
# block_4_project
# block_4_project_BN
# block_4_add
# block_5_expand
# block_5_expand_BN
# block_5_expand_relu
# block_5_depthwise
# block_5_depthwise_BN
# block_5_depthwise_relu
# block_5_project
# block_5_project_BN
# block_5_add
# block_6_expand
# block_6_expand_BN
# block_6_expand_relu
# block_6_pad
# block_6_depthwise
# block_6_depthwise_BN
# block_6_depthwise_relu
# block_6_project
# block_6_project_BN
# block_7_expand
# block_7_expand_BN
# block_7_expand_relu
# block_7_depthwise
# block_7_depthwise_BN
# block_7_depthwise_relu
# block_7_project
# block_7_project_BN
# block_7_add
# block_8_expand
# block_8_expand_BN
# block_8_expand_relu
# block_8_depthwise
# block_8_depthwise_BN
# block_8_depthwise_relu
# block_8_project
# block_8_project_BN
# block_8_add
# block_9_expand
# block_9_expand_BN
# block_9_expand_relu
# block_9_depthwise
# block_9_depthwise_BN
# block_9_depthwise_relu
# block_9_project
# block_9_project_BN
# block_9_add
# block_10_expand
# block_10_expand_BN
# block_10_expand_relu
# block_10_depthwise
# block_10_depthwise_BN
# block_10_depthwise_relu
# block_10_project
# block_10_project_BN
# block_11_expand
# block_11_expand_BN
# block_11_expand_relu
# block_11_depthwise
# block_11_depthwise_BN
# block_11_depthwise_relu
# block_11_project
# block_11_project_BN
# block_11_add
# block_12_expand
# block_12_expand_BN
# block_12_expand_relu
# block_12_depthwise
# block_12_depthwise_BN
# block_12_depthwise_relu
# block_12_project
# block_12_project_BN
# block_12_add
# block_13_expand
# block_13_expand_BN
# block_13_expand_relu
# block_13_pad
# block_13_depthwise
# block_13_depthwise_BN
# block_13_depthwise_relu
# block_13_project
# block_13_project_BN
# block_14_expand
# block_14_expand_BN
# block_14_expand_relu
# block_14_depthwise
# block_14_depthwise_BN
# block_14_depthwise_relu
# block_14_project
# block_14_project_BN
# block_14_add
# block_15_expand
# block_15_expand_BN
# block_15_expand_relu
# block_15_depthwise
# block_15_depthwise_BN
# block_15_depthwise_relu
# block_15_project
# block_15_project_BN
# block_15_add
# block_16_expand
# block_16_expand_BN
# block_16_expand_relu
# block_16_depthwise
# block_16_depthwise_BN
# block_16_depthwise_relu
# block_16_project
# block_16_project_BN
# Conv_1
# Conv_1_bn
# out_relu

# %%
last_output = output_of_last_layer(pre_trained_model)
# Out:
# last layer output shape:  (None, 7, 7, 160)
# last layer output:  KerasTensor(type_spec=TensorSpec(shape=(None, 7, 7, 160), dtype=tf.float32, name=None), name='block_14_project/Conv2D:0', description="created by layer 'block_14_project'")

# %%
# Creating model
def create_final_model(pre_trained_model, last_output):
  # Flatten the output layer to 1 dimension
  x = layers.Flatten()(last_output)
  x = layers.Dense(1024, activation='relu')(x)
  x = layers.Dropout(0.2)(x)    
  x = layers.Dense(6, activation='softmax')(x)          

  model = Model(inputs=pre_trained_model.input, outputs=x)
  
  model.compile(optimizer=Adam(learning_rate=0.001),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']) 

  return model

# %%
# Saving model in a variable
model = create_final_model(pre_trained_model, last_output)

# Inspect parameters
total_params = model.count_params()
num_trainable_params = sum([w.shape.num_elements() for w in model.trainable_weights])

print(f"There are {total_params:,} total parameters in this model.")
print(f"There are {num_trainable_params:,} trainable parameters in this model.")
# Out:
# There are 9,075,398 total parameters in this model.
# There are 8,035,334 trainable parameters in this model.

# %%
# Training the model
history = model.fit(train_generator,
                    steps_per_epoch = 3,
                    epochs=15,
                    validation_data=validation_generator)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 15s 5s/step - loss: 14.3522 - accuracy: 0.2182 - val_loss: 26.9813 - val_accuracy: 0.1667
# Epoch 2/15
# 3/3 [==============================] - 15s 6s/step - loss: 20.5159 - accuracy: 0.2133 - val_loss: 10.6670 - val_accuracy: 0.3000
# Epoch 3/15
# 3/3 [==============================] - 11s 4s/step - loss: 13.4120 - accuracy: 0.2182 - val_loss: 7.1532 - val_accuracy: 0.5111
# Epoch 4/15
# 3/3 [==============================] - 13s 4s/step - loss: 7.5186 - accuracy: 0.4364 - val_loss: 7.1495 - val_accuracy: 0.3333
# Epoch 5/15
# 3/3 [==============================] - 12s 6s/step - loss: 5.6837 - accuracy: 0.3545 - val_loss: 2.6943 - val_accuracy: 0.4667
# Epoch 6/15
# 3/3 [==============================] - 14s 5s/step - loss: 2.8306 - accuracy: 0.3867 - val_loss: 3.1539 - val_accuracy: 0.2556
# Epoch 7/15
# 3/3 [==============================] - 11s 5s/step - loss: 3.5817 - accuracy: 0.2455 - val_loss: 1.4247 - val_accuracy: 0.5778
# Epoch 8/15
# 3/3 [==============================] - 11s 5s/step - loss: 1.4590 - accuracy: 0.6000 - val_loss: 1.4240 - val_accuracy: 0.6667
# Epoch 9/15
# 3/3 [==============================] - 11s 4s/step - loss: 1.8302 - accuracy: 0.5273 - val_loss: 1.5587 - val_accuracy: 0.6000
# Epoch 10/15
# 3/3 [==============================] - 11s 4s/step - loss: 1.3477 - accuracy: 0.6000 - val_loss: 0.7284 - val_accuracy: 0.6778
# Epoch 11/15
# 3/3 [==============================] - 11s 4s/step - loss: 1.0749 - accuracy: 0.5909 - val_loss: 0.9419 - val_accuracy: 0.5778
# Epoch 12/15
# 3/3 [==============================] - 15s 6s/step - loss: 0.9717 - accuracy: 0.6400 - val_loss: 0.6729 - val_accuracy: 0.7667
# Epoch 13/15
# 3/3 [==============================] - 15s 5s/step - loss: 0.9071 - accuracy: 0.6867 - val_loss: 0.7382 - val_accuracy: 0.7556
# Epoch 14/15
# 3/3 [==============================] - 15s 6s/step - loss: 0.7246 - accuracy: 0.7267 - val_loss: 0.5704 - val_accuracy: 0.8000
# Epoch 15/15
# 3/3 [==============================] - 14s 5s/step - loss: 0.7412 - accuracy: 0.7273 - val_loss: 0.6981 - val_accuracy: 0.6778

# %%
pd.DataFrame(history.history)
# Out:
#          loss  accuracy   val_loss  val_accuracy
# 0   14.352201  0.218182  26.981316      0.166667
# 1   20.515942  0.213333  10.667012      0.300000
# 2   13.411959  0.218182   7.153228      0.511111
# 3    7.518581  0.436364   7.149549      0.333333
# 4    5.683711  0.354545   2.694342      0.466667
# 5    2.830571  0.386667   3.153898      0.255556
# 6    3.581696  0.245455   1.424673      0.577778
# 7    1.458969  0.600000   1.423966      0.666667
# 8    1.830246  0.527273   1.558651      0.600000
# 9    1.347672  0.600000   0.728354      0.677778
# 10   1.074937  0.590909   0.941888      0.577778
# 11   0.971739  0.640000   0.672943      0.766667
# 12   0.907085  0.686667   0.738174      0.755556
# 13   0.724611  0.726667   0.570369      0.800000
# 14   0.741201  0.727273   0.698131      0.677778

# %% [markdown]
# # Prediction Test

# %%
# predicting images

labels = ["Binturong", "Koala", "Lemur Catta", "Sanford's Brown Lemur", "Siau Island Tarsier", "Walrus"]

src = 'EYEAM Image Data'
res_dict = {}

import time
st = time.time()

for animals in os.listdir(src):
    for img in os.listdir(os.path.join(src, animals)):
        path = os.path.join(src, animals, img)

        #path = 'EYEAM Image Data\\Binturong\\Binturong_2.jpeg'
        img = tf.keras.utils.load_img(path, target_size=(224, 224))
        x = tf.keras.utils.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = x/255

        images = np.vstack([x])
        classes = labels[np.argmax(model.predict(images))]

        #print(path)
        #print(classes)

        if classes in res_dict.keys():
          res_dict[classes] += 1
        else:
          res_dict[classes] = 1

et = time.time()

print('Time elapsed: {} seconds.'.format(et-st))

res_dict
# Out:
# 1/1 [==============================] - 0s 96ms/step
# EYEAM Image Data\Binturong\Binturong_1.jpg
# Binturong
# 1/1 [==============================] - 0s 61ms/step
# EYEAM Image Data\Binturong\Binturong_10.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 49ms/step
# EYEAM Image Data\Binturong\Binturong_11.jpg
# Koala
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Binturong\Binturong_12.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 50ms/step
# EYEAM Image Data\Binturong\Binturong_13.jpg
# Binturong
# 1/1 [==============================] - 0s 50ms/step
# EYEAM Image Data\Binturong\Binturong_14.jpg
# Koala
# 1/1 [==============================] - 0s 56ms/step
# EYEAM Image Data\Binturong\Binturong_15.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 49ms/step
# EYEAM Image Data\Binturong\Binturong_16.jpeg
# Koala
# 1/1 [==============================] - 0s 54ms/step
# EYEAM Image Data\Binturong\Binturong_17.jpg
# Binturong
# 1/1 [==============================] - 0s 46ms/step
# EYEAM Image Data\Binturong\Binturong_18.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 48ms/step
# EYEAM Image Data\Binturong\Binturong_19.jpg
# Koala
# 1/1 [==============================] - 0s 51ms/step
# EYEAM Image Data\Binturong\Binturong_2.jpeg
# Binturong
# 1/1 [==============================] - 0s 48ms/step
# EYEAM Image Data\Binturong\Binturong_20.jpg
# Koala
# 1/1 [==============================] - 0s 57ms/step
# EYEAM Image Data\Binturong\Binturong_21.jpg
# Koala
# 1/1 [==============================] - 0s 48ms/step
# EYEAM Image Data\Binturong\Binturong_22.jpg
# Binturong
# 1/1 [==============================] - 0s 49ms/step
# EYEAM Image Data\Binturong\Binturong_23.jpg
# Koala
# 1/1 [==============================] - 0s 49ms/step
# EYEAM Image Data\Binturong\Binturong_24.jpg
# Koala
# 1/1 [==============================] - 0s 58ms/step
# EYEAM Image Data\Binturong\Binturong_25.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 54ms/step
# EYEAM Image Data\Binturong\Binturong_26.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Binturong\Binturong_27.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Binturong\Binturong_28.jpg
# Binturong
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Binturong\Binturong_29.jpg
# Binturong
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Binturong\Binturong_3.jpeg
# Binturong
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Binturong\Binturong_30.jpg
# Binturong
# 1/1 [==============================] - 0s 65ms/step
# EYEAM Image Data\Binturong\Binturong_31.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Binturong\Binturong_32.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 60ms/step
# EYEAM Image Data\Binturong\Binturong_33.jpg
# Koala
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Binturong\Binturong_34.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 65ms/step
# EYEAM Image Data\Binturong\Binturong_35.jpg
# Binturong
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Binturong\Binturong_36.jpg
# Binturong
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Binturong\Binturong_37.jpg
# Binturong
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Binturong\Binturong_38.jpg
# Binturong
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Binturong\Binturong_39.png
# Koala
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Binturong\Binturong_4.jpg
# Binturong
# 1/1 [==============================] - 0s 63ms/step
# EYEAM Image Data\Binturong\Binturong_40.png
# Binturong
# 1/1 [==============================] - 0s 65ms/step
# EYEAM Image Data\Binturong\Binturong_41.png
# Koala
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Binturong\Binturong_42.png
# Binturong
# 1/1 [==============================] - 0s 60ms/step
# EYEAM Image Data\Binturong\Binturong_43.png
# Binturong
# 1/1 [==============================] - 0s 63ms/step
# EYEAM Image Data\Binturong\Binturong_44.png
# Koala
# 1/1 [==============================] - 0s 61ms/step
# EYEAM Image Data\Binturong\Binturong_45.png
# Koala
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Binturong\Binturong_46.png
# Koala
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Binturong\Binturong_47.png
# Binturong
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Binturong\Binturong_48.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 63ms/step
# EYEAM Image Data\Binturong\Binturong_49.jpg
# Koala
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Binturong\Binturong_5.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Binturong\Binturong_50.jpg
# Binturong
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Binturong\Binturong_6.jpg
# Binturong
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Binturong\Binturong_7.jpg
# Binturong
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Binturong\Binturong_8.jpg
# Koala
# 1/1 [==============================] - 0s 66ms/step
# EYEAM Image Data\Binturong\Binturong_9.jpg
# Binturong
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Koala\Koala_1.jpg
# Koala
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Koala\Koala_10.jpg
# Koala
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Koala\Koala_11.jpg
# Koala
# 1/1 [==============================] - 0s 89ms/step
# EYEAM Image Data\Koala\Koala_12.jpg
# Koala
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Koala\Koala_13.jpg
# Koala
# 1/1 [==============================] - 0s 90ms/step
# EYEAM Image Data\Koala\Koala_14.jpg
# Koala
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Koala\Koala_15.jpg
# Koala
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Koala\Koala_16.jpg
# Koala
# 1/1 [==============================] - 0s 78ms/step
# EYEAM Image Data\Koala\Koala_17.jpg
# Koala
# 1/1 [==============================] - 0s 84ms/step
# EYEAM Image Data\Koala\Koala_18.jpg
# Koala
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Koala\Koala_19.jpg
# Koala
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Koala\Koala_2.jpg
# Koala
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Koala\Koala_20.jpeg
# Koala
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Koala\Koala_21.jpg
# Koala
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Koala\Koala_22.jpeg
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Koala\Koala_23.jpg
# Koala
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Koala\Koala_24.jpg
# Koala
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Koala\Koala_25.jpg
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Koala\Koala_26.jpg
# Koala
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Koala\Koala_27.png
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Koala\Koala_28.jpg
# Koala
# 1/1 [==============================] - 0s 61ms/step
# EYEAM Image Data\Koala\Koala_29.jpg
# Koala
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Koala\Koala_3.jpeg
# Koala
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Koala\Koala_30.jpg
# Koala
# 1/1 [==============================] - 0s 82ms/step
# EYEAM Image Data\Koala\Koala_31.jpg
# Koala
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Koala\Koala_32.jpg
# Koala
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Koala\Koala_33.jpg
# Koala
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Koala\Koala_34.jpg
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Koala\Koala_35.jpg
# Koala
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Koala\Koala_36.jpg
# Koala
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Koala\Koala_37.jpg
# Koala
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Koala\Koala_38.png
# Koala
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Koala\Koala_39.png
# Koala
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Koala\Koala_4.jpg
# Koala
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Koala\Koala_40.png
# Koala
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Koala\Koala_41.png
# Koala
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Koala\Koala_42.png
# Koala
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Koala\Koala_43.png
# Koala
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Koala\Koala_44.png
# Koala
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Koala\Koala_45.png
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Koala\Koala_46.png
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Koala\Koala_47.png
# Koala
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Koala\Koala_48.png
# Koala
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Koala\Koala_49.jpg
# Koala
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Koala\Koala_5.jpg
# Koala
# 1/1 [==============================] - 0s 86ms/step
# EYEAM Image Data\Koala\Koala_50.jpg
# Koala
# 1/1 [==============================] - 0s 82ms/step
# EYEAM Image Data\Koala\Koala_6.jpg
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Koala\Koala_7.jpg
# Koala
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Koala\Koala_8.jpg
# Koala
# 1/1 [==============================] - 0s 78ms/step
# EYEAM Image Data\Koala\Koala_9.jpg
# Koala
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_1.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_10.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_11.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_12.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_13.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 100ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_14.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_15.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_16.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 63ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_17.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_18.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_19.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_2.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_20.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_21.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_22.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_23.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_24.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 81ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_25.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_26.jpg
# Koala
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_27.png
# Lemur Catta
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_28.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_29.png
# Koala
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_3.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_30.png
# Lemur Catta
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_31.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 99ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_32.png
# Lemur Catta
# 1/1 [==============================] - 0s 105ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_33.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 134ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_34.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 96ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_35.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 93ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_36.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 85ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_37.jpg
# Koala
# 1/1 [==============================] - 0s 94ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_38.png
# Koala
# 1/1 [==============================] - 0s 89ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_39.jpeg
# Lemur Catta
# 1/1 [==============================] - 0s 102ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_4.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 99ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_40.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 91ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_41.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_42.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 82ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_43.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_44.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_45.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_46.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_47.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_48.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 62ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_49.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_5.jpg
# Koala
# 1/1 [==============================] - 0s 65ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_50.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_6.jpg
# Koala
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_7.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_8.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Lemur Catta\Lemur Catta_9.jpg
# Lemur Catta
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_1.jpg
# Koala
# 1/1 [==============================] - 0s 78ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_10.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 81ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_11.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 94ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_12.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_13.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_14.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_15.jpg
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_16.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_17.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_18.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_19.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_2.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_20.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_21.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_22.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_23.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 79ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_24.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_25.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_26.JPG
# Koala
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_27.JPG
# Koala
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_28.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_29.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_3.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_30.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_31.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_32.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_33.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_34.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_35.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 82ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_36.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_37.png
# Lemur Catta
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_38.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 65ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_39.jpg
# Koala
# 1/1 [==============================] - 0s 62ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_4.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_40.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 59ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_41.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 62ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_42.png
# Koala
# 1/1 [==============================] - 0s 58ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_43.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 56ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_44.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 57ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_45.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 54ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_46.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 62ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_47.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_48.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_49.png
# Koala
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_5.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_50.png
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_6.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_7.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_8.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Sanford_s Brown Lemur\Sanford_s Brown Lemur_9.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 66ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_1.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_10.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_11.jpg
# Koala
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_12.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_13.jpg
# Koala
# 1/1 [==============================] - 0s 150ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_14.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_15.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_16.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_17.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_18.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 75ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_19.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_2.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 92ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_20.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 78ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_21.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_22.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 79ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_23.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_24.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_25.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_26.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_27.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 79ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_28.jpg
# Koala
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_29.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_3.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_30.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_31.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 84ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_32.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 66ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_33.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 61ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_34.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 63ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_35.png
# Koala
# 1/1 [==============================] - 0s 79ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_36.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 56ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_37.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 63ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_38.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 66ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_39.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 68ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_4.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 64ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_40.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_41.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_42.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_43.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_44.png
# Siau Island Tarsier
# 1/1 [==============================] - 0s 72ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_45.jpeg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_46.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_47.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_48.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_49.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_5.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 81ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_50.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 85ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_6.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_7.jpg
# Sanford's Brown Lemur
# 1/1 [==============================] - 0s 84ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_8.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Siau Island Tarsier\Siau Island Tarsier_9.jpg
# Siau Island Tarsier
# 1/1 [==============================] - 0s 77ms/step
# EYEAM Image Data\Walrus\Walrus_1.jpg
# Walrus
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Walrus\Walrus_10.jpg
# Walrus
# 1/1 [==============================] - 0s 71ms/step
# EYEAM Image Data\Walrus\Walrus_11.jpg
# Walrus
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Walrus\Walrus_12.jpg
# Walrus
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Walrus\Walrus_13.jpg
# Walrus
# 1/1 [==============================] - 0s 84ms/step
# EYEAM Image Data\Walrus\Walrus_14.jpg
# Walrus
# 1/1 [==============================] - 0s 85ms/step
# EYEAM Image Data\Walrus\Walrus_15.jpg
# Walrus
# 1/1 [==============================] - 0s 84ms/step
# EYEAM Image Data\Walrus\Walrus_16.jpg
# Walrus
# 1/1 [==============================] - 0s 90ms/step
# EYEAM Image Data\Walrus\Walrus_17.jpeg
# Walrus
# 1/1 [==============================] - 0s 80ms/step
# EYEAM Image Data\Walrus\Walrus_18.jpg
# Walrus
# 1/1 [==============================] - 0s 81ms/step
# EYEAM Image Data\Walrus\Walrus_19.jpg
# Walrus
# 1/1 [==============================] - 0s 76ms/step
# EYEAM Image Data\Walrus\Walrus_2.jpg
# Walrus
# 1/1 [==============================] - 0s 91ms/step
# EYEAM Image Data\Walrus\Walrus_20.jpg
# Walrus
# 1/1 [==============================] - 0s 85ms/step
# EYEAM Image Data\Walrus\Walrus_21.jpg
# Walrus
# 1/1 [==============================] - 0s 88ms/step
# EYEAM Image Data\Walrus\Walrus_22.jpg
# Walrus
# 1/1 [==============================] - 0s 101ms/step
# EYEAM Image Data\Walrus\Walrus_23.png
# Walrus
# 1/1 [==============================] - 0s 153ms/step
# EYEAM Image Data\Walrus\Walrus_24.jpg
# Walrus
# 1/1 [==============================] - 0s 89ms/step
# EYEAM Image Data\Walrus\Walrus_25.jpg
# Walrus
# 1/1 [==============================] - 0s 81ms/step
# EYEAM Image Data\Walrus\Walrus_26.jpg
# Walrus
# 1/1 [==============================] - 0s 86ms/step
# EYEAM Image Data\Walrus\Walrus_27.jpg
# Walrus
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Walrus\Walrus_28.jpg
# Walrus
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Walrus\Walrus_29.jpg
# Walrus
# 1/1 [==============================] - 0s 83ms/step
# EYEAM Image Data\Walrus\Walrus_3.jpg
# Walrus
# 1/1 [==============================] - 0s 101ms/step
# EYEAM Image Data\Walrus\Walrus_30.jpg
# Walrus
# 1/1 [==============================] - 0s 95ms/step
# EYEAM Image Data\Walrus\Walrus_31.jpg
# Walrus
# 1/1 [==============================] - 0s 84ms/step
# EYEAM Image Data\Walrus\Walrus_32.jpg
# Walrus
# 1/1 [==============================] - 0s 102ms/step
# EYEAM Image Data\Walrus\Walrus_33.jpg
# Walrus
# 1/1 [==============================] - 0s 74ms/step
# EYEAM Image Data\Walrus\Walrus_34.jpg
# Walrus
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Walrus\Walrus_35.jpg
# Walrus
# 1/1 [==============================] - 0s 67ms/step
# EYEAM Image Data\Walrus\Walrus_36.jpg
# Walrus
# 1/1 [==============================] - 0s 69ms/step
# EYEAM Image Data\Walrus\Walrus_37.jpg
# Walrus
# 1/1 [==============================] - 0s 60ms/step
# EYEAM Image Data\Walrus\Walrus_38.png
# Walrus
# 1/1 [==============================] - 0s 59ms/step
# EYEAM Image Data\Walrus\Walrus_39.png
# Walrus
# 1/1 [==============================] - 0s 56ms/step
# EYEAM Image Data\Walrus\Walrus_4.jpg
# Walrus
# 1/1 [==============================] - 0s 57ms/step
# EYEAM Image Data\Walrus\Walrus_40.png
# Walrus
# 1/1 [==============================] - 0s 62ms/step
# EYEAM Image Data\Walrus\Walrus_41.png
# Walrus
# 1/1 [==============================] - 0s 53ms/step
# EYEAM Image Data\Walrus\Walrus_42.png
# Walrus
# 1/1 [==============================] - 0s 54ms/step
# EYEAM Image Data\Walrus\Walrus_43.png
# Walrus
# 1/1 [==============================] - 0s 55ms/step
# EYEAM Image Data\Walrus\Walrus_44.png
# Walrus
# 1/1 [==============================] - 0s 58ms/step
# EYEAM Image Data\Walrus\Walrus_45.jpg
# Walrus
# 1/1 [==============================] - 0s 70ms/step
# EYEAM Image Data\Walrus\Walrus_46.jpg
# Walrus
# 1/1 [==============================] - 0s 73ms/step
# EYEAM Image Data\Walrus\Walrus_47.jpg
# Walrus
# 1/1 [==============================] - 0s 57ms/step
# EYEAM Image Data\Walrus\Walrus_48.jpg
# Walrus
# 1/1 [==============================] - 0s 56ms/step
# EYEAM Image Data\Walrus\Walrus_49.jpg
# Walrus
# 1/1 [==============================] - 0s 52ms/step
# EYEAM Image Data\Walrus\Walrus_5.jpg
# Walrus
# 1/1 [==============================] - 0s 54ms/step
# EYEAM Image Data\Walrus\Walrus_50.jpg
# Walrus
# 1/1 [==============================] - 0s 53ms/step
# EYEAM Image Data\Walrus\Walrus_6.jpg
# Walrus
# 1/1 [==============================] - 0s 54ms/step
# EYEAM Image Data\Walrus\Walrus_7.jpg
# Walrus
# 1/1 [==============================] - 0s 54ms/step
# EYEAM Image Data\Walrus\Walrus_8.jpg
# Walrus
# 1/1 [==============================] - 0s 56ms/step
# EYEAM Image Data\Walrus\Walrus_9.jpg
# Walrus
# Time elapsed: 53.72525382041931 seconds.
# {'Binturong': 22,
#  "Sanford's Brown Lemur": 65,
#  'Koala': 83,
#  'Lemur Catta': 39,
#  'Siau Island Tarsier': 41,
#  'Walrus': 50}

# %% [markdown]
# # Saving the Model

# %%
# Saving model into h5 format
from datetime import datetime
date = datetime.now().strftime("%Y_%m_%d-%I-%M-%S-%p")
model.save(f'H5 Models/model_1_mobilenetv2 ({date}).h5')

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, label="Training Accuracy", color='red')
plt.plot(epochs, val_acc, label="Validation Accuracy", color='blue')
plt.title('Training and Validation Accuracy')
plt.ylabel('Values')
plt.xlabel('Epochs')
plt.legend(loc="upper left")
plt.show()
print("")

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs,loss, label="Training Loss", color='red')
plt.plot(epochs,val_loss, label="Validation Loss", color='blue')
plt.title('Training and Validation Loss')
plt.ylabel('Values')
plt.xlabel('Epochs')
plt.legend(loc="upper right")
plt.show()
